# %% [markdown]
# <a href="https://colab.research.google.com/github/zachregester/personal-project/blob/main/PythonPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

url = 'https://restcountries.com/v3.1/all?fields=name,population'

def get_data(url):
  r = requests.get(url)
  return r.json()

def parse_data(resp):
  name_block = resp.get('name',{})
  native_block = name_block.get('nativeName', {})

  if native_block:

    for key, val in native_block.items():
      native_official = val.get('official')
      native_common = val.get('common')
      break

  else:
      native_official = None
      native_common = None

  name_dict = {
      "Official": name_block.get('official'),
      "Native Official": native_official,
      "Native Common": native_common,
      "Population": resp.get('population')
  }

  return name_dict

data = get_data(url)

final = []

for item in data:
  result = parse_data(item)
  final.append(result)

print(final)

df = pd.DataFrame(final)

print(df)
# Out:
# [{'Official': 'Tunisian Republic', 'Native Official': 'الجمهورية التونسية', 'Native Common': 'تونس', 'Population': 11818618}, {'Official': 'Principality of Andorra', 'Native Official': "Principat d'Andorra", 'Native Common': 'Andorra', 'Population': 77265}, {'Official': 'Socialist Republic of Vietnam', 'Native Official': 'Cộng hòa xã hội chủ nghĩa Việt Nam', 'Native Common': 'Việt Nam', 'Population': 97338583}, {'Official': 'Republic of Ecuador', 'Native Official': 'República del Ecuador', 'Native Common': 'Ecuador', 'Population': 17643060}, {'Official': 'Commonwealth of Puerto Rico', 'Native Official': 'Commonwealth of Puerto Rico', 'Native Common': 'Puerto Rico', 'Population': 3194034}, {'Official': 'United States of America', 'Native Official': 'United States of America', 'Native Common': 'United States', 'Population': 329484123}, {'Official': 'South Georgia and the South Sandwich Islands', 'Native Official': 'South Georgia and the South Sandwich Islands', 'Native Common': 'South Georgia', 'Population': 30}, {'Official': 'State of Israel', 'Native Official': 'دولة إسرائيل', 'Native Common': 'إسرائيل', 'Population': 9216900}, {'Official': 'United Kingdom of Great Britain and Northern Ireland', 'Native Official': 'United Kingdom of Great Britain and Northern Ireland', 'Native Common': 'United Kingdom', 'Population': 67215293}, {'Official': 'Virgin Islands', 'Native Official': 'Virgin Islands', 'Native Common': 'British Virgin Islands', 'Population': 30237}, {'Official': 'Republic of the Union of Myanmar', 'Native Official': 'ပြည်ထောင်စု သမ္မတ မြန်မာနိုင်ငံတော်', 'Native Common': 'မြန်မာ', 'Population': 54409794}, {'Official': 'Republic of Poland', 'Native Official': 'Rzeczpospolita Polska', 'Native Common': 'Polska', 'Population': 37950802}, {'Official': 'Turks and Caicos Islands', 'Native Official': 'Turks and Caicos Islands', 'Native Common': 'Turks and Caicos Islands', 'Population': 38718}, {'Official': 'Islamic Republic of Afghanistan', 'Native Official': 'جمهوری اسلامی افغانستان', 'Native Common': 'افغانستان', 'Population': 40218234}, {'Official': 'Guadeloupe', 'Native Official': 'Guadeloupe', 'Native Common': 'Guadeloupe', 'Population': 400132}, {'Official': 'Republic of Kenya', 'Native Official': 'Republic of Kenya', 'Native Common': 'Kenya', 'Population': 53771300}, {'Official': 'American Samoa', 'Native Official': 'American Samoa', 'Native Common': 'American Samoa', 'Population': 55197}, {'Official': 'Republic of Angola', 'Native Official': 'República de Angola', 'Native Common': 'Angola', 'Population': 32866268}, {'Official': 'Kingdom of Bhutan', 'Native Official': 'འབྲུག་རྒྱལ་ཁབ་', 'Native Common': 'འབྲུག་ཡུལ་', 'Population': 771612}, {'Official': 'Republic of Malta', 'Native Official': 'Republic of Malta', 'Native Common': 'Malta', 'Population': 525285}, {'Official': 'Bailiwick of Jersey', 'Native Official': 'Bailiwick of Jersey', 'Native Common': 'Jersey', 'Population': 100800}, {'Official': 'Russian Federation', 'Native Official': 'Российская Федерация', 'Native Common': 'Россия', 'Population': 144104080}, {'Official': 'Federal Democratic Republic of Nepal', 'Native Official': 'नेपाल संघीय लोकतान्त्रिक गणतन्त्र', 'Native Common': 'नेपाल', 'Population': 29136808}, {'Official': 'Republic of Guinea-Bissau', 'Native Official': 'República da Guiné-Bissau', 'Native Common': 'Guiné-Bissau', 'Population': 1967998}, {'Official': 'Republic of Iraq', 'Native Official': 'جمهورية العراق', 'Native Common': 'العراق', 'Population': 40222503}, {'Official': 'Republic of the Sudan', 'Native Official': 'جمهورية السودان', 'Native Common': 'السودان', 'Population': 43849269}, {'Official': 'French Polynesia', 'Native Official': 'Polynésie française', 'Native Common': 'Polynésie française', 'Population': 280904}, {'Official': 'Republic of Djibouti', 'Native Official': 'جمهورية جيبوتي', 'Native Common': 'جيبوتي\u200e', 'Population': 988002}, {'Official': 'Republic of Mozambique', 'Native Official': 'República de Moçambique', 'Native Comm ...
#                                  Official  \
# 0                       Tunisian Republic
# 1                 Principality of Andorra
# 2           Socialist Republic of Vietnam
# 3                     Republic of Ecuador
# 4             Commonwealth of Puerto Rico
# ..                                    ...
# 245                      Kingdom of Tonga
# 246                              Malaysia
# 247                      Republic of Fiji
# 248                               Jamaica
# 249  United States Minor Outlying Islands
#
#                           Native Official  \
# 0                      الجمهورية التونسية
# 1                     Principat d'Andorra
# 2      Cộng hòa xã hội chủ nghĩa Việt Nam
# 3                   República del Ecuador
# 4             Commonwealth of Puerto Rico
# ..                                    ...
# 245                      Kingdom of Tonga
# 246                              Malaysia
# 247                      Republic of Fiji
# 248                               Jamaica
# 249  United States Minor Outlying Islands
#
#                             Native Common  Population
# 0                                    تونس    11818618
# 1                                 Andorra       77265
# 2                                Việt Nam    97338583
# 3                                 Ecuador    17643060
# 4                             Puerto Rico     3194034
# ..                                    ...         ...
# 245                                 Tonga      105697
# 246                              Malaysia    32365998
# 247                                  Fiji      896444
# 248                               Jamaica     2961161
# 249  United States Minor Outlying Islands         300
#
# [250 rows x 4 columns]
